# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import warnings
from pandas.plotting import scatter_matrix
from sklearn import metrics
import seaborn as sn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from xgboost import XGBClassifier
from xgboost import plot_importance
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from collections import Counter
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import RepeatedStratifiedKFold
from skopt import BayesSearchCV
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE, BorderlineSMOTE, SMOTENC, SVMSMOTE, KMeansSMOTE, ADASYN
from sklearn.model_selection import GridSearchCV
from imblearn.pipeline import Pipeline
from data_processing import (identify_merger, clean_hcris_before_2010, imputation_method, resampling)

# %%
# ignore warnings
warnings.filterwarnings("ignore")
# Set the display options
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',200)
pd.options.mode.use_inf_as_na = True

# %% [markdown]
# # Data preparation

# %% [markdown]
# Firstly, I upload the verified data from Lina and identify the potential mergers (details see identify_merger() in data_processing.py).\
# Return the data after identification as a dataframe (df1).\
# Drop the 'Year of change' after 2012.

# %%
verified_data = identify_merger()
verified_data.drop(verified_data[verified_data['Year of change']==2017].index,inplace=True)
verified_data.drop(verified_data[verified_data['Year of change']==2016].index,inplace=True)
verified_data.drop(verified_data[verified_data['Year of change']==2015].index,inplace=True)
verified_data.drop(verified_data[verified_data['Year of change']==2014].index,inplace=True)
verified_data.drop(verified_data[verified_data['Year of change']==2013].index,inplace=True)
# Out:
#          id  Type of closure  \
# 0     10009              1.0
# 1     10010              5.0
# 2     10015              1.0
# 3     10025              4.0
# 4     10027              1.0
# ..      ...              ...
# 365  670018              1.0
# 366  670021              4.0
# 367  670029              5.0
# 368  670052              4.0
# 369  670066              4.0
#
#     Type of change (Convert/close/merge/change names)  Year of change  merged
# 0                                               Close          2012.0       0
# 1                                                Open             NaN       0
# 2                                               Close          2011.0       0
# 3                                         Open/merger          2013.0       1
# 4                                               Close          2013.0       0
# ..                                                ...             ...     ...
# 365      Close, reopen in 2015 but probably partially          2014.0       0
# 366                                 Open, name change          2011.0       1
# 367                                              Open             NaN       0
# 368                      Open, merger and name change          2013.0       1
# 369                      Open, merger and name change          2015.0       1
#
# [370 rows x 5 columns]

# %% [markdown]
# Upload HCRIS data 2001-2012

# %%
# HCRIS 2001-2012 except 2010
hcris_2012 = pd.read_csv('ime_gme2552_10_2012.csv')
hcris_2011 = pd.read_csv('ime_gme2552_10_2011.csv')
hcris_2009 = pd.read_csv('ime_gme2552_96_2009.csv')
hcris_2008 = pd.read_csv('ime_gme2552_96_2008.csv')
hcris_2007 = pd.read_csv('ime_gme2552_96_2007.csv')
hcris_2006 = pd.read_csv('ime_gme2552_96_2006.csv')
hcris_2005 = pd.read_csv('ime_gme2552_96_2005.csv')
hcris_2004 = pd.read_csv('ime_gme2552_96_2004.csv')
hcris_2003 = pd.read_csv('ime_gme2552_96_2003.csv')
hcris_2002 = pd.read_csv('ime_gme2552_96_2002.csv')
hcris_2001 = pd.read_csv('ime_gme2552_96_2001.csv')
# HCRIS 2010
hcris_2010_1 = pd.read_csv('ime_gme2552_10_2010.csv')
hcris_2010_2 = pd.read_csv('ime_gme2552_96_2010.csv')
hcris_2010 = pd.merge(hcris_2010_1, hcris_2010_2, how='outer')

# %% [markdown]
# HCRIS_2012 data as another dataframe (df2).

# %%
# Match the column names with df1
hcris_2012.rename(columns={'provider': 'id'}, inplace=True)
print(f"The shape of original HCRIS 2012:{hcris_2012.shape}")
# Out:
# The shape of original HCRIS 2012:(6227, 41)

# %% [markdown]
# Check how many common (merged) hospitals between verified and HCRIS.

# %%
verified_hcris_common = pd.merge(verified_data, hcris_2012)
verified_hcris_common_merged = verified_hcris_common.loc[verified_hcris_common['merged'].isin([1])]
print(f'Common hospitals: {verified_hcris_common.shape}')
print(f'Common merged hospitals: {verified_hcris_common_merged.shape}')
verified_hcris_common_merged.head(20)
# Out:
# Common hospitals: (122, 45)
# Common merged hospitals: (56, 45)
#         id  Type of closure Type of change (Convert/close/merge/change names)  \
# 2    10137              3.0              Service reduction, specialty clinics
# 6    30100              3.0                                      Open, merger
# 7    30100              3.0                                      Open, merger
# 9    50016              3.0                        Open/merged multiple times
# 17   50752              4.0                                 Open, name change
# 18   70001              4.0                      Open, merger and name change
# 19   70015              4.0                      Open, merger and name change
# 26  110219              4.0                                 Open, name change
# 27  140051              4.0                                 Open, name change
# 29  150003              4.0                                 Open, name change
# 34  170195              4.0                                 Open, name change
# 35  180149              4.0                      Open, merger and name change
# 37  190161              4.0                                 Open, name change
# 41  200002              4.0                      Open, merger and name change
# 43  200040              4.0                      Open, merger and name change
# 44  210007              4.0                      Open, merger and name change
# 45  210054              4.0                      Open, merger and name change
# 46  220082              3.0                          Close, service reduction
# 47  220082              3.0                          Close, service reduction
# 49  230101              4.0                                 Open, name change
#
#     Year of change  merged  prvdr_num        fyb     fybstr         fye  \
# 2              NaN       1      10137  10/1/2011  01-OCT-11   9/30/2012
# 6              NaN       1      30100  10/1/2011  01-OCT-11   6/30/2012
# 7              NaN       1      30100   7/1/2012  01-JUL-12   11/7/2012
# 9              NaN       1      50016   7/1/2012  01-JUL-12    1/9/2013
# 17             NaN       1      50752   1/1/2012  01-JAN-12  12/31/2012
# 18             NaN       1      70001  10/1/2011  01-OCT-11   9/11/2012
# 19             NaN       1      70015  10/1/2011  01-OCT-11   9/30/2012
# 26             NaN       1     110219   6/1/2012  01-JUN-12  12/31/2012
# 27             NaN       1     140051  10/1/2011  01-OCT-11   9/30/2012
# 29             NaN       1     150003   1/1/2012  01-JAN-12  12/31/2012
# 34             NaN       1     170195   1/1/2012  01-JAN-12  12/31/2012
# 35             NaN       1     180149   7/1/2012  01-JUL-12   6/30/2013
# 37             NaN       1     190161   7/1/2012  01-JUL-12   6/24/2013
# 41             NaN       1     200002  10/1/2011  01-OCT-11   9/30/2012
# 43             NaN       1     200040   6/1/2012  01-JUN-12   5/31/2013
# 44             NaN       1     210007   7/1/2012  01-JUL-12  11/30/2012
# 45             NaN       1     210054   1/1/2012  01-JAN-12  12/10/2012
# 46          2012.0       1     220082  10/1/2011  01-OCT-11   6/30/2012
# 47          2012.0       1     220082   7/1/2012  01-JUL-12   9/30/2012
# 49             NaN       1     230101  10/1/2011  01-OCT-11   6/25/2012
#
#        fyestr        status                             hospital_name  \
# 2   30-SEP-12  As Submitted  COOPER GREEN MERCY HOSPITAL
# 6   30-JUN-12      Reopened  CARONDELET HEART AND VASCULAR INSTIT
# 7   07-NOV-12       Settled  CARONDELET HEART AND VASCULAR INSTIT
# 9   09-JAN-13       Settled  ARROYO GRANDE COMMUNITY HOSPITAL
# 17  31-DEC-12       Settled  BROTMAN MEDICAL CENTER
# 18  11-SEP-12       Settled  HOSPITAL OF SAINT RAPHAEL
# 19  30-SEP-12       Settled  NEW MILFORD HOSPITAL
# 26  31-DEC-12      Reopened  SOUTH FULTON MEDICAL CENTER
# 27  30-SEP-12       Settled  SKOKIE HOSPITAL
# 29  31-DEC-12      Reopened  ST. ELIZABETH CENTRAL
# 34  31-DEC-12      Reopened  HEARTLAND SURGICAL SPECIALTY HOSPITA
# 35  30-JUN-13       Amended  WESTLAKE REGIONAL HOSPITAL
# 37  24-JUN-13       Settled  W.O. MOSS REG. MEDICAL CENTER
# 41  30-SEP-12       Settled  MILES MEMORIAL HOSPITAL
# 43  31-MAY-13      Reopened  H. D. GOODALL HOSPITAL
# 44  30-NOV-12       Settled  ST. JOSEPH MEDICAL CENTER
# 45  10-DEC-12       Settled  SOUTHERN MARYLAND HOSPITAL
# 46  30-JUN-12      Reopened  SAINTS MEDICAL CENTER
# 47  30-SEP-12       Settled  SAINTS MEDICAL CENTER
# 49  25-JUN-12       Settled  ST. FRANCIS HOSPITAL
#
#                                  street_addr  \
# 2   1515 SIXTH AVENUE SOUTH
# 6   4888 NORTH STONE DRIVE
# 7   4888 NORTH STONE DRIVE
# 9   345 SOUTH HALCYON ROAD
# 17  3828 DELMAS TERRACE
# 18  1450 CHAPEL STREET
# 19  21 ELM STREET
# 26  1170 CLEVELAND AVE
# 27  9600 GROSS POINT ROAD
# 29  1501 HARTFORD STREET
# 34  10720 NALL AVENUE
# 35  901 WESTLAKE DRIVE
# 37  1000 WALTERS STREET
# 41  BRISTOL ROAD
# 43  25 JUNE STREET
# 44  7601 OSLER DRIVE
# 45  7503 SURRATTS ROAD
# 46  ONE HOSPITAL DRIVE
# 47  ONE HOSPITAL DRIVE
# 49  3410 LUDINGTON STREET
#
#                                       po_box  \
# 2                                        NaN
# 6                                        NaN
# 7                                        NaN
# 9                                        NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 26                                       NaN
# 27                                       NaN
# 29                                       NaN
# 34                                       NaN
# 35  1269
# 37                                       NaN
# 41                                       NaN
# 43                                       NaN
# 44                                       NaN
# 45                                       NaN
# 46                                       NaN
# 47                                       NaN
# 49                                       NaN
#
#                                         city  \
# 2   BIRMINGHAM
# 6   TUCSON
# 7   TUCSON
# 9   ARROYO GRANDE
# 17  CULVER CITY
# 18  NEW HAVEN
# 19  NEW MILFORD
# 26  EAST POINT
# 27  SKOKIE
# 29  LAFAYETTE
# 34  OVERLAND PARK
# 35  COLUMBIA
# 37  LAKE CHARLES
# 41  DAMARISCOTTA
# 43  SANFORD
# 44  TOWSON
# 45  CLINTON
# 46  LOWELL
# 47  LOWELL
# 49  ESCANABA
#
#                                        state  \
# 2   AL
# 6   AZ
# 7   AZ
# 9   CA
# 17  CA
# 18  CT
# 19  CT
# 26  GA
# 27  IL
# 29  IN
# 34  KS
# 35  KY
# 37  LA
# 41  ME
# 43  ME
# 44  MD
# 45  MD
# 46  MA
# 47  MA
# 49  MI
#
#                                     zip_code  \
# 2   35233
# 6   85704-
# 7   85704-
# 9   93420
# 17  90232
# 18  06511
# 19  06776
# 26  30344
# 27  60076
# 29  47904-
# 34  66211
# 35  42728-
# 37  70607
# 41  04543-
# 43  04073-
# 44  21204
# 45  20735
# 46  01852
# 47  01852
# 49  49829-0787
#
#                                       county        ime1  ime2  ime3  \
# 2   JEFFERSON                                    55245.0   NaN   NaN
# 6   PIMA                                             NaN   NaN   NaN
# 7   PIMA                                             NaN   NaN   NaN
# 9   SAN LUIS OBISPO                                  NaN   NaN   NaN
# 17  LOS ANGELES                                      NaN   NaN   NaN
# 18  NEW HAVEN                                 15952772.0   NaN   NaN
# 19  UNITED STATES                                    NaN   NaN   NaN
# 26  FULTON                                       62535.0   NaN   NaN
# 27  COOK                                       2666080.0   NaN   NaN
# 29  TIPPECANOE                                       NaN   NaN   NaN
# 34  JOHNSON                                          NaN   NaN   NaN
# 35  ADAIR                                            NaN   NaN   NaN
# 37  CALCASIEU                                     1209.0   NaN   NaN
# 41  LINCOLN                                          NaN   NaN   NaN
# 43  YORK                                             NaN   NaN   NaN
# 44  BALTIMORE                                        NaN   NaN   NaN
# 45  PRINCE GEORGES                                   NaN   NaN   NaN
# 46  MIDDLESEX                                        NaN   NaN   NaN
# 47  MIDDLESEX                                        NaN   NaN   NaN
# 49  DELTA                                            NaN   NaN   NaN
#
#          dsh1      dsh2  dsh3  dshpct  gme_part_a  gme_part_b   beds  \
# 2    384237.0       NaN   NaN  0.4494    111732.0     74964.0  149.0
# 6         NaN       NaN   NaN     NaN         NaN         NaN   60.0
# 7         NaN       NaN   NaN     NaN         NaN         NaN   60.0
# 9         NaN       NaN   NaN     NaN         NaN         NaN   53.0
# 17  7086722.0       NaN   NaN  0.2970         NaN         NaN  283.0
# 18  6427300.0       NaN   NaN  0.0853   6012769.0   1411530.0  411.0
# 19        NaN       NaN   NaN     NaN         NaN         NaN   85.0
# 26  1923494.0       NaN   NaN  0.3551    116885.0     32265.0  198.0
# 27  2955137.0       NaN   NaN  0.0915   1098461.0    429646.0  128.0
# 29   305820.0  101619.0   NaN  0.0442         NaN         NaN   94.0
# 34        NaN       NaN   NaN     NaN         NaN         NaN   48.0
# 35   269570.0       NaN   NaN  0.1434         NaN         NaN   49.0
# 37    29189.0       NaN   NaN  0.0608      1013.0      2730.0   18.0
# 41        NaN       NaN   NaN     NaN         NaN         NaN   38.0
# 43   494731.0       NaN   NaN  0.0787         NaN         NaN   49.0
# 44        NaN       NaN   NaN     NaN         NaN         NaN  267.0
# 45  9614442.0       NaN   NaN  0.2241         NaN         NaN  239.0
# 46  2477043.0       NaN   NaN  0.1199         NaN         NaN  157.0
# 47   747568.0       NaN   NaN  0.1331         NaN         NaN  157.0
# 49   259477.0       NaN   NaN  0.0793         NaN         NaN   48.0
#
#     bed_days  medicare_days  medicaid_days     days      intres    employees  \
# 2    54385.0          792.0         6456.0  12741.0   25.000000   650.150024
# 6    16440.0         2692.0          513.0   6563.0         NaN   219.309998
# 7     7800.0          584.0          143.0   1487.0         NaN   175.119995
# 9    19345.0         2067.0           99.0   7578.0         NaN   255.000000
# 17  103578.0        16896.0         5263.0  35870.0         NaN   607.000000
# 18  142617.0        43996.0        10199.0  90680.0  127.730003  2954.719971
# 19   31110.0         4591.0          822.0   8537.0         NaN   429.799988
# 26   42372.0         4546.0         4697.0  14984.0    6.130000   453.799988
# 27   52096.0        19373.0         4579.0  31015.0   20.379999   762.799988
# 29   34404.0         6966.0         1521.0  11913.0         NaN   535.570007
# 34   11376.0          185.0            1.0    577.0         NaN    76.519997
# 35   17885.0         2336.0          341.0   3035.0         NaN   135.419998
# 37    6486.0          407.0          391.0   2621.0    1.530000   359.500000
# 41   13908.0         4224.0          678.0   7040.0         NaN   231.089996
# 43   17885.0         4002.0         1015.0   7601.0         NaN   635.650024
# 44   40851.0        12688.0         1059.0  28346.0         NaN   613.669983
# 45   82455.0        26938.0        11848.0  60995.0         NaN  1718.000000
# 46   43018.0         9942.0         1680.0  18432.0         NaN   840.309998
# 47   14444.0         2786.0         1017.0   5654.0         NaN   839.309998
# 49   12912.0         1993.0          287.0   3872.0         NaN   451.140015
#
#     volunteers  medicare_disch  medicaid_disch  discharges  \
# 2          NaN           153.0          1783.0      2488.0
# 6          NaN           615.0           155.0      1637.0
# 7          NaN           135.0            42.0       414.0
# 9          NaN           573.0            19.0      2273.0
# 17         NaN          2893.0           894.0      7021.0
# 18         NaN          7743.0          2886.0     18852.0
# 19        5.26          1008.0           244.0      2288.0
# 26         NaN           789.0           888.0      2831.0
# 27         NaN          3811.0           409.0      6644.0
# 29         NaN          1609.0           406.0      2910.0
# 34         NaN            78.0             1.0       268.0
# 35         NaN           427.0            98.0       679.0
# 37         NaN            88.0            76.0       632.0
# 41         NaN           888.0           255.0      1618.0
# 43         NaN          1065.0           341.0      2058.0
# 44         NaN          2828.0           178.0      6385.0
# 45         NaN          6776.0          3154.0     18561.0
# 46         NaN          2262.0           385.0      4696.0
# 47         NaN           654.0           152.0      1487.0
# 49         NaN           559.0            30.0      1124.0
#
#     medicaid_hmo_discharges  medicaid_hmo_ipf_subprovider  \
# 2                       NaN                           NaN
# 6                       NaN                           NaN
# 7                       NaN                           NaN
# 9                       NaN                           NaN
# 17                      NaN                           NaN
# 18                      NaN                           NaN
# 19                      NaN                           NaN
# 26                      NaN                           NaN
# 27                      NaN                           NaN
# 29                      NaN                           NaN
# 34                      NaN                           NaN
# 35                      NaN                           NaN
# 37                      NaN                           NaN
# 41                      NaN                           NaN
# 43                      NaN                           NaN
# 44                      NaN                           NaN
# 45                      NaN                           NaN
# 46                      NaN                           NaN
# 47                      NaN                           NaN
# 49                      NaN                           NaN
#
#     medicaid_hmo_irf_subprovider  medicaid_ipf_subprovider  \
# 2                            NaN                       NaN
# 6                            NaN                       NaN
# 7                            NaN                       NaN
# 9                            NaN                       NaN
# 17                           NaN                     756.0
# 18                           NaN                     246.0
# 19                           NaN                       NaN
# 26                           NaN                       NaN
# 27                           NaN                       NaN
# 29                           NaN                       NaN
# 34                           NaN                       NaN
# 35                           NaN                     149.0
# 37                           NaN                       NaN
# 41                           NaN                       NaN
# 43                           NaN                       NaN
# 44                           NaN                       NaN
# 45                           NaN                       NaN
# 46                           NaN                       NaN
# 47                           NaN                       NaN
# 49                           NaN                       NaN
#
#     medicaid_irf_subprovider  total_discharges_subprovider_ipf  \
# 2                        NaN                              62.0
# 6                        NaN                               NaN
# 7                        NaN                               NaN
# 9                        4.0                               NaN
# 17                      11.0                            1736.0
# 18                       NaN                             712.0
# 19                       NaN                               NaN
# 26                       NaN                               NaN
# 27                       NaN                               NaN
# 29                       NaN                               NaN
# 34                       NaN                               NaN
# 35                       NaN                             409.0
# 37                       NaN                               NaN
# 41                       NaN                               NaN
# 43                       NaN                               NaN
# 44                       NaN                               NaN
# 45                       NaN                               NaN
# 46                       NaN                               NaN
# 47                       NaN                               NaN
# 49                       NaN                               NaN
#
#     total_discharges_subprovider_irf
# 2                                NaN
# 6                                NaN
# 7                                NaN
# 9                              369.0
# 17                             417.0
# 18                             379.0
# 19                               NaN
# 26                               NaN
# 27                               NaN
# 29                               NaN
# 34                               NaN
# 35                               NaN
# 37                               NaN
# 41                               NaN
# 43                               NaN
# 44                               NaN
# 45                               NaN
# 46                               NaN
# 47                               NaN
# 49                               NaN

# %% [markdown]
# Merge two dataframes by hospital ids.

# %%
verified_hcris_data = pd.merge(verified_data, hcris_2012, how='outer')
# Fill the value of column 'merged' in hosp_data not included in verified_data with 0
verified_hcris_data = verified_hcris_data.fillna({'merged':0})
print(verified_hcris_data.shape)
# Out:
# (6408, 45)

# %% [markdown]
# # Data cleaning

# %% [markdown]
# Drop duplicates and keep the latest date information.

# %%
# Return DataFrame with duplicate rows removed except for the id with the recent date.
verified_hcris_data.drop_duplicates(subset=['id'], keep='last', inplace=True)
verified_hcris_data.sort_values(by='id', ascending=True, inplace = True)
verified_hcris_data.reset_index(drop=True, inplace = True)
print(verified_hcris_data.shape)
verified_hcris_data.head(20)
# Out:
# (6313, 45)
#        id  Type of closure Type of change (Convert/close/merge/change names)  \
# 0   10001              NaN                                               NaN
# 1   10005              NaN                                               NaN
# 2   10006              NaN                                               NaN
# 3   10007              NaN                                               NaN
# 4   10008              NaN                                               NaN
# 5   10009              1.0                                             Close
# 6   10010              5.0                                              Open
# 7   10011              NaN                                               NaN
# 8   10012              NaN                                               NaN
# 9   10015              1.0                                             Close
# 10  10016              NaN                                               NaN
# 11  10018              NaN                                               NaN
# 12  10019              NaN                                               NaN
# 13  10021              NaN                                               NaN
# 14  10022              NaN                                               NaN
# 15  10023              NaN                                               NaN
# 16  10024              NaN                                               NaN
# 17  10025              NaN                                               NaN
# 18  10027              NaN                                               NaN
# 19  10029              NaN                                               NaN
#
#     Year of change  merged  prvdr_num        fyb     fybstr         fye  \
# 0              NaN     0.0    10001.0  10/1/2011  01-OCT-11   9/30/2012
# 1              NaN     0.0    10005.0  10/1/2011  01-OCT-11   9/30/2012
# 2              NaN     0.0    10006.0   7/1/2012  01-JUL-12   6/30/2013
# 3              NaN     0.0    10007.0  10/1/2011  01-OCT-11   9/30/2012
# 4              NaN     0.0    10008.0   1/1/2012  01-JAN-12  12/31/2012
# 5           2012.0     0.0        NaN        NaN        NaN         NaN
# 6              NaN     0.0        NaN        NaN        NaN         NaN
# 7              NaN     0.0    10011.0   7/1/2012  01-JUL-12   6/30/2013
# 8              NaN     0.0    10012.0   4/1/2012  01-APR-12   3/31/2013
# 9           2011.0     0.0        NaN        NaN        NaN         NaN
# 10             NaN     0.0    10016.0   1/1/2012  01-JAN-12  12/31/2012
# 11             NaN     0.0    10018.0  10/1/2011  01-OCT-11   9/30/2012
# 12             NaN     0.0    10019.0  10/1/2011  01-OCT-11   9/30/2012
# 13             NaN     0.0    10021.0  10/1/2011  01-OCT-11   9/30/2012
# 14             NaN     0.0    10022.0   4/1/2012  01-APR-12   3/31/2013
# 15             NaN     0.0    10023.0   7/1/2012  01-JUL-12   6/30/2013
# 16             NaN     0.0    10024.0   1/1/2012  01-JAN-12  12/31/2012
# 17             NaN     0.0    10025.0   7/1/2012  01-JUL-12   6/30/2013
# 18             NaN     0.0    10027.0   7/1/2012  01-JUL-12    2/4/2013
# 19             NaN     0.0    10029.0  10/1/2011  01-OCT-11   9/30/2012
#
#        fyestr        status                             hospital_name  \
# 0   30-SEP-12       Amended  SOUTHEAST ALABAMA MEDICAL CENTER
# 1   30-SEP-12      Reopened  MARSHALL MEDICAL CENTER - SOUTH
# 2   30-JUN-13      Reopened  ELIZA COFFEE MEMORIAL HOSPITAL
# 3   30-SEP-12       Settled  MIZELL MEMORIAL HOSPITAL
# 4   31-DEC-12       Amended  CRENSHAW COMMUNITY HOSPITAL
# 5         NaN           NaN                                       NaN
# 6         NaN           NaN                                       NaN
# 7   30-JUN-13       Amended  ST. VINCENTS EAST
# 8   31-MAR-13       Settled  DEKALB REGIONAL MEDICAL CENTER
# 9         NaN           NaN                                       NaN
# 10  31-DEC-12       Settled  SHELBY BAPTIST MEDICAL CENTER
# 11  30-SEP-12  As Submitted  CALLAHAN EYE FOUNDATION HOSP
# 12  30-SEP-12       Settled  HELEN KELLER HOSPITAL
# 13  30-SEP-12       Settled  DALE MEDICAL CENTER
# 14  31-MAR-13       Settled  CHEROKEE MEDICAL CENTER
# 15  30-JUN-13       Settled  BAPTIST MEDICAL CENTER SOUTH
# 16  31-DEC-12       Settled  JACKSON HOSPITAL AND CLINIC  INC
# 17  30-JUN-13       Settled  GEORGE H. LANIER HOSPITAL
# 18  04-FEB-13  As Submitted  ELBA GENERAL HOSPITAL
# 19  30-SEP-12       Settled  EAST ALABAMA MEDICAL CENTER
#
#                                  street_addr  \
# 0   1108 ROSS CLARK CIRCLE
# 1   2505 U.S. HIGHWAY 431
# 2   205 MARENGO STREET
# 3   702 MAIN STREET
# 4   CRENSHAW COMMUNITY HOSPITAL
# 5                                        NaN
# 6                                        NaN
# 7   50 MEDICAL PARK DRIVE EAST
# 8   200 MEDICAL CENTER DRIVE
# 9                                        NaN
# 10  1000 FIRST STREET NORTH
# 11  1720 UNIVERSITY BOULEVARD
# 12  1300 SOUTH MONTGOMERY AVENUE
# 13  126 HOSPITAL
# 14  100 NORTHWOOD DRIVE
# 15  2105  EAST SOUTH BOULEVARD
# 16  1725 PINE STREET
# 17  4800 48TH STREET
# 18  987 DRAYTON STREET
# 19  2000 PEPPERELL PKWY
#
#                                       po_box  \
# 0   6987
# 1                                        NaN
# 2   818
# 3   429
# 4   101 HOSPITAL CIRCLE
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12  610
# 13                                       NaN
# 14                                       NaN
# 15  11010
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
#
#                                         city  \
# 0   DOTHAN
# 1   BOAZ
# 2   FLORENCE
# 3   OPP
# 4   LUVERNE
# 5                                        NaN
# 6                                        NaN
# 7   BIRMINGHAM
# 8   FORT PAYNE
# 9                                        NaN
# 10  ALABASTER
# 11  BIRMINGHAM
# 12  SHEFFIELD
# 13  OZARK
# 14  CENTRE
# 15  MONTGOMERY
# 16  MONTGOMERY
# 17  VALLEY
# 18  ELBA
# 19  OPELIKA
#
#                                        state  \
# 0   AL
# 1   AL
# 2   AL
# 3   AL
# 4   AL
# 5                                        NaN
# 6                                        NaN
# 7   AL
# 8   AL
# 9                                        NaN
# 10  AL
# 11  AL
# 12  AL
# 13  AL
# 14  AL
# 15  AL
# 16  AL
# 17  AL
# 18  AL
# 19  AL
#
#                                     zip_code  \
# 0   36301
# 1   35957-
# 2   35630
# 3   36462-
# 4   36049
# 5                                        NaN
# 6                                        NaN
# 7   35235-
# 8   35967
# 9                                        NaN
# 10  35007
# 11  35233-
# 12  35660-
# 13  36360-
# 14  35960-
# 15  36116-
# 16  36106-1109
# 17  36854
# 18  35323
# 19  36802-
#
#                                       county       ime1  ime2  ime3  \
# 0   HOUSTON                                         NaN   NaN   NaN
# 1   MARSHALL                                        NaN   NaN   NaN
# 2   LAUDERDALE                                      NaN   NaN   NaN
# 3   COVINGTON                                       NaN   NaN   NaN
# 4   CRENSHAW                                        NaN   NaN   NaN
# 5                                        NaN        NaN   NaN   NaN
# 6                                        NaN        NaN   NaN   NaN
# 7   JEFFERSON                                 1670142.0   NaN   NaN
# 8   DEKALB                                          NaN   NaN   NaN
# 9                                        NaN        NaN   NaN   NaN
# 10  SHELBY                                          NaN   NaN   NaN
# 11  JEFFERSON                                   55065.0   NaN   NaN
# 12  COLBERT                                         NaN   NaN   NaN
# 13  DALE                                            NaN   NaN   NaN
# 14  CHEROKEE                                        NaN   NaN   NaN
# 15  MONTGOMERY                                2831573.0   NaN   NaN
# 16  MONTGOMERY                                      NaN   NaN   NaN
# 17  CHAMBERS                                        NaN   NaN   NaN
# 18  COFFEE                                          NaN   NaN   NaN
# 19  LEE                                             NaN   NaN   NaN
#
#           dsh1  dsh2  dsh3  dshpct  gme_part_a  gme_part_b   beds  bed_days  \
# 0    8633626.0   NaN   NaN  0.1498         NaN         NaN  408.0  149328.0
# 1    2891397.0   NaN   NaN  0.1253         NaN         NaN  204.0   74664.0
# 2    3498027.0   NaN   NaN  0.0951         NaN         NaN  358.0  130670.0
# 3     185865.0   NaN   NaN  0.0533         NaN         NaN   78.0   28548.0
# 4     287870.0   NaN   NaN  0.1713         NaN         NaN   29.0   10614.0
# 5          NaN   NaN   NaN     NaN         NaN         NaN    NaN       NaN
# 6          NaN   NaN   NaN     NaN         NaN         NaN    NaN       NaN
# 7    2023583.0   NaN   NaN  0.0612    787021.0    229995.0  279.0  101835.0
# 8     928833.0   NaN   NaN  0.1200         NaN         NaN   97.0   35405.0
# 9          NaN   NaN   NaN     NaN         NaN         NaN    NaN       NaN
# 10   2216102.0   NaN   NaN  0.0882         NaN         NaN  193.0   70572.0
# 11         NaN   NaN   NaN     NaN     30907.0    491552.0   12.0    4392.0
# 12   2402331.0   NaN   NaN  0.1381         NaN         NaN  185.0   67710.0
# 13    477348.0   NaN   NaN  0.1200         NaN         NaN   77.0   28182.0
# 14    198467.0   NaN   NaN  0.1108         NaN         NaN   45.0   16425.0
# 15  11055136.0   NaN   NaN  0.2591    444188.0    517814.0  363.0  132495.0
# 16   4447886.0   NaN   NaN  0.1244         NaN         NaN  255.0   93330.0
# 17   1276420.0   NaN   NaN  0.1832         NaN         NaN   84.0   30660.0
# 18     12764.0   NaN   NaN  0.1204         NaN         NaN   20.0    4380.0
# 19   5189715.0   NaN   NaN  0.1212         NaN         NaN  258.0   94428.0
#
#     medicare_days  medicaid_days     days     intres    employees  volunteers  \
# 0         42785.0        15986.0  87760.0        NaN  2160.600098         NaN
# 1         17787.0         6381.0  36415.0        NaN  1056.020020         NaN
# 2         28599.0         7909.0  52665.0        NaN   968.530029         NaN
# 3          4122.0          619.0   5867.0        NaN   153.449997         NaN
# 4          1764.0          668.0   3240.0        NaN   106.699997         NaN
# 5             NaN            NaN      NaN        NaN          NaN         NaN
# 6             NaN            NaN      NaN        NaN          NaN         NaN
# 7         23284.0        10013.0  75795.0  14.660000  1101.239990         NaN
# 8          5771.0         2818.0  13469.0        NaN   371.500000         NaN
# 9             NaN            NaN      NaN        NaN          NaN         NaN
# 10        17256.0         8645.0  52461.0        NaN   822.969971         NaN
# 11           73.0           16.0    117.0   7.000000   146.000000         NaN
# 12        14171.0         6819.0  29534.0        NaN   591.669983         NaN
# 13         3536.0         1624.0   7810.0        NaN   270.019989         NaN
# 14         2735.0          383.0   3830.0        NaN   107.620003         NaN
# 15        24504.0        27050.0  83797.0  42.150002  1963.599976         NaN
# 16        26523.0        10905.0  63984.0        NaN  1223.790039         NaN
# 17         8038.0         3096.0  15163.0        NaN   336.820007         NaN
# 18           99.0           16.0    164.0        NaN    89.400002         NaN
# 19        28498.0        12099.0  62347.0        NaN  1905.290039         NaN
#
#     medicare_disch  medicaid_disch  discharges  medicaid_hmo_discharges  \
# 0           7790.0          3931.0     17435.0                      NaN
# 1           3797.0          1291.0      9168.0                      NaN
# 2           5039.0          1765.0     10862.0                      NaN
# 3            819.0           133.0      1302.0                      NaN
# 4            374.0           166.0       744.0                      NaN
# 5              NaN             NaN         NaN                      NaN
# 6              NaN             NaN         NaN                      NaN
# 7           4117.0          1683.0     14380.0                      NaN
# 8           1416.0           844.0      3758.0                      NaN
# 9              NaN             NaN         NaN                      NaN
# 10          3364.0          2094.0     10594.0                      NaN
# 11            23.0             3.0        85.0                      NaN
# 12          2950.0          1530.0      7044.0                      NaN
# 13           760.0           376.0      1973.0                      NaN
# 14           386.0           114.0       759.0                      NaN
# 15          5124.0          3837.0     16789.0                      NaN
# 16          4926.0          2890.0     14474.0                      NaN
# 17          1106.0           511.0      2718.0                      NaN
# 18            28.0             7.0        46.0                      NaN
# 19          5266.0          2243.0     15507.0                      NaN
#
#     medicaid_hmo_ipf_subprovider  medicaid_hmo_irf_subprovider  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# 5                            NaN                           NaN
# 6                            NaN                           NaN
# 7                            NaN                           NaN
# 8                            NaN                           NaN
# 9                            NaN                           NaN
# 10                           NaN                           NaN
# 11                           NaN                           NaN
# 12                           NaN                           NaN
# 13                           NaN                           NaN
# 14                           NaN                           NaN
# 15                           NaN                           NaN
# 16                           NaN                           NaN
# 17                           NaN                           NaN
# 18                           NaN                           NaN
# 19                           NaN                           NaN
#
#     medicaid_ipf_subprovider  medicaid_irf_subprovider  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                      104.0                       NaN
# 5                        NaN                       NaN
# 6                        NaN                       NaN
# 7                       27.0                       4.0
# 8                       11.0                       NaN
# 9                        NaN                       NaN
# 10                       NaN                       NaN
# 11                       NaN                       NaN
# 12                       NaN                       NaN
# 13                       NaN                       NaN
# 14                       NaN                       NaN
# 15                     547.0                       NaN
# 16                       NaN                       NaN
# 17                       NaN                       NaN
# 18                       NaN                       NaN
# 19                       NaN                       NaN
#
#     total_discharges_subprovider_ipf  total_discharges_subprovider_irf
# 0                              215.0                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                              262.0                               NaN
# 4                              540.0                               NaN
# 5                                NaN                               NaN
# 6                                NaN                               NaN
# 7                              421.0                             232.0
# 8                              332.0                               NaN
# 9                                NaN                               NaN
# 10                               NaN                               NaN
# 11                               NaN                               NaN
# 12                               NaN                               NaN
# 13                             368.0                               NaN
# 14                               NaN                               NaN
# 15                            1923.0                               NaN
# 16                               NaN                               NaN
# 17                               NaN                               NaN
# 18                               NaN                               NaN
# 19                               NaN                               NaN

# %% [markdown]
# After combining the two dataframes, I found some hospitals with blank information for almost all columns except 'id' and 'merged'.\
# They're likely to close or merge before year 2012.\
# So fill those hospitals information with previous HCRIS data.

# %% [markdown]
# Clean the previous HCRIS data.

# %%
# 2011
hcris_2011.rename(columns={'provider': 'id'}, inplace=True)
hcris_2011.drop_duplicates(subset=['id'], keep='last', inplace=True)
hcris_2011.sort_values(by='id', ascending=True, inplace=True)
hcris_2011.reset_index(drop=True, inplace=True)
# 2010
hcris_2010.rename(columns={'provider': 'id'}, inplace=True)
hcris_2010[hcris_2010["id"].duplicated(keep="last") == True]
hcris_2010.drop_duplicates(subset=['id'], keep='last', inplace=True)
hcris_2010.sort_values(by='id', ascending=True, inplace=True)
hcris_2010.reset_index(drop=True, inplace=True)
# 
hcris_2009 = clean_hcris_before_2010(hcris_2009)
hcris_2008 = clean_hcris_before_2010(hcris_2008)
hcris_2007 = clean_hcris_before_2010(hcris_2007)
hcris_2006 = clean_hcris_before_2010(hcris_2006)
hcris_2005 = clean_hcris_before_2010(hcris_2005)
hcris_2004 = clean_hcris_before_2010(hcris_2004)
hcris_2003 = clean_hcris_before_2010(hcris_2003)
hcris_2002 = clean_hcris_before_2010(hcris_2002)
hcris_2001 = clean_hcris_before_2010(hcris_2001)
